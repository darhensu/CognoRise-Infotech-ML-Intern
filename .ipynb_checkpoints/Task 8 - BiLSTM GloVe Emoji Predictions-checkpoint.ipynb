# %% [markdown]
# # Emoji Prediction Using Bi-directional LSTM with GloVe Embeddings

# %% [markdown]
# This project aims to predict appropriate emojis based on the content of text messages or social media posts. Leveraging the power of natural language processing (NLP), we train a machine learning model using a dataset of text paired with emojis. The model uses Bi-directional Long Short-Term Memory (LSTM) networks with pre-trained GloVe word embeddings to capture the contextual meaning of the text and predict the most relevant emoji. By utilizing these advanced deep learning techniques, the model can understand subtle nuances in language and suggest emojis that match the sentiment or context of the input text, making it an exciting application for enhancing social media interactions, messaging apps, and more.
#
# The project focuses on:
#
# Text preprocessing and feature extraction
# Implementing Bi-directional LSTM with GloVe embeddings
# Training a model to predict emoji labels
# Evaluation using accuracy and other metrics
# The final model can be used in various applications where text-based emoji prediction can enhance user experience.

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import re
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Bidirectional, LSTM, Dense, Dropout
from tensorflow.keras.initializers import Constant

# %% [markdown]
# # Load and Explore Dataset

# %%
df1 = pd.read_csv(r'C:\Users\user\Desktop\CognoRise Infotech ML Intern\data\emoji_prediction_training_data.csv')
df1
# Out:
#        Unnamed: 0                                               TEXT  Label
# 0               0  Vacation wasted ! #vacation2017 #photobomb #ti...      0
# 1               1  Oh Wynwood, you’re so funny! : @user #Wynwood ...      1
# 2               2  Been friends since 7th grade. Look at us now w...      2
# 3               3  This is what it looks like when someone loves ...      3
# 4               4  RT @user this white family was invited to a Bl...      3
# ...           ...                                                ...    ...
# 69995       69995  Yes, I call Galina "my Bubie" Go follow my bea...      3
# 69996       69996    I SEA you, Seattle @ Ballard Seafood Festival\n     16
# 69997       69997  If one of my daughters is wearing this and ask...      2
# 69998       69998  Guess who whoop people on THEIR homecoming?! #...      3
# 69999       69999  We Love you Robbie @ Heritage Memorial Cemeter...     14
#
# [70000 rows x 3 columns]

# %%
df2 = pd.read_csv(r'C:\Users\user\Desktop\CognoRise Infotech ML Intern\data\emoji_prediction_mapping_data.csv')
df2.head()
# Out:
#    Unnamed: 0 emoticons  number
# 0           0         😜       0
# 1           1         📸       1
# 2           2         😍       2
# 3           3         😂       3
# 4           4         😉       4

# %% [markdown]
# # Merge Dataset

# %%
df = pd.merge(df1, df2, left_on='Label', right_on='number')
df.head()
# Out:
#    Unnamed: 0_x                                               TEXT  Label  \
# 0             0  Vacation wasted ! #vacation2017 #photobomb #ti...      0
# 1             1  Oh Wynwood, you’re so funny! : @user #Wynwood ...      1
# 2             2  Been friends since 7th grade. Look at us now w...      2
# 3             3  This is what it looks like when someone loves ...      3
# 4             4  RT @user this white family was invited to a Bl...      3
#
#    Unnamed: 0_y emoticons  number
# 0             0         😜       0
# 1             1         📸       1
# 2             2         😍       2
# 3             3         😂       3
# 4             3         😂       3

# %%
df = df.drop(['Unnamed: 0_x', 'Unnamed: 0_y', 'number'], axis=1)
df.head()
# Out:
#                                                 TEXT  Label emoticons
# 0  Vacation wasted ! #vacation2017 #photobomb #ti...      0         😜
# 1  Oh Wynwood, you’re so funny! : @user #Wynwood ...      1         📸
# 2  Been friends since 7th grade. Look at us now w...      2         😍
# 3  This is what it looks like when someone loves ...      3         😂
# 4  RT @user this white family was invited to a Bl...      3         😂

# %%
print("Dataset size:", len(df))
# Out:
# Dataset size: 70000

# %% [markdown]
# # Text cleaning

# %%
def clean_text(text):
    text = text.lower()  # lowercase
    text = re.sub(r'http\S+|www.\S+', '', text)  # remove URLs
    text = re.sub(r'@\w+|#\w+', '', text)  # remove mentions and hashtags
    text = re.sub(r'[^\w\s]', '', text)  # remove punctuation
    return text

# %%
df['cleaned_text'] = df['TEXT'].apply(clean_text)

# %% [markdown]
# # Preparing text for model

# %%
texts = df['cleaned_text'].values
labels = df['Label'].values

# %% [markdown]
# # Tokenizing

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)
word_index = tokenizer.word_index

# %%
maxlen = 100  
X_train = pad_sequences(sequences, maxlen=maxlen)

# %% [markdown]
# # Load GloVe embeddings

# %%
embedding_dim = 300
embedding_index = {}
with open(r'C:\Users\user\Downloads\glove.42B.300d.txt', encoding='utf-8') as f:  # replace with actual path to GloVe file
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embedding_index[word] = coefs

# %% [markdown]
# # Prepare embedding matrix

# %%
num_words = len(word_index) + 1
embedding_matrix = np.zeros((num_words, embedding_dim))
for word, i in word_index.items():
    embedding_vector = embedding_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %% [markdown]
# # Model setup

# %%
model = Sequential([
    Embedding(num_words, embedding_dim, embeddings_initializer=Constant(embedding_matrix),
              trainable=False),  
    Bidirectional(LSTM(128, return_sequences=True)),
    Dropout(0.2),
    Bidirectional(LSTM(128)),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(len(np.unique(labels)), activation='softmax')
])

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # Train model

# %%
model.fit(X_train, labels, epochs=5, batch_size=64, verbose=1)
# Out:
# Epoch 1/5
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1696s 2s/step - accuracy: 0.2589 - loss: 2.5704
# Epoch 2/5
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 908s 830ms/step - accuracy: 0.3198 - loss: 2.3330
# Epoch 3/5
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 904s 826ms/step - accuracy: 0.3376 - loss: 2.2497
# Epoch 4/5
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 833s 761ms/step - accuracy: 0.3567 - loss: 2.1727
# Epoch 5/5
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 840s 767ms/step - accuracy: 0.3789 - loss: 2.0760

# %%
# create a dictionary to map labels (number) to emojis
emoji_labels = dict(zip(df['Label'], df['emoticons']))

# %% [markdown]
# # Predictions

# %%
test_df = pd.read_csv(r'C:\Users\user\Desktop\CognoRise Infotech ML Intern\data\emoji_prediction_test_data.csv')  # Replace with your actual file path
test_texts = test_df['TEXT'].values  # Assuming the text column is named 'TEXT'

# %%
# tokenize the test texts
test_sequences = tokenizer.texts_to_sequences(test_texts)

# %%
# pad the sequences to ensure uniform input length
maxlen = 100  
X_test = pad_sequences(test_sequences, maxlen=maxlen)

# %%
# make predictions using the trained model
predictions = model.predict(X_test)
# Out:
# 812/812 ━━━━━━━━━━━━━━━━━━━━ 178s 217ms/step

# %%
# convert predictions to emoji labels (argmax to get the class index)
predicted_emojis = [np.argmax(pred) for pred in predictions]

# %%
# map predicted emoji indices to emoji labels using the `emoji_labels` dictionary
predicted_emoji_labels = [emoji_labels[pred] for pred in predicted_emojis]

# %%
# output the predictions
for text, emoji in zip(test_texts, predicted_emoji_labels):
    print(f"Text: {text}\nPredicted Emoji: {emoji}\n")
# Out:
# Text: Thought this was cool...#Repost (get_repost)・・・Colorview. by shay_images…
#
# Predicted Emoji: 📸
#
# Text: Happy 4th! Corte madera parade. #everytownusa #merica @ Perry's on…
#
# Predicted Emoji: 🇺🇸
#
# Text: Luv. Or at least something close to it. @ Union Hill, Richmond, Virginia
#
# Predicted Emoji: ❤
#
# Text: There's a slice of pie under that whipped cream. #HouseofPies @ House of Pies
#
# Predicted Emoji: 😍
#
# Text: #thankyou for your thank you We adore you both + plan on moreeeee! Hosting your #wedding was…
#
# Predicted Emoji: ❤
#
# Text: the SPECIAL4U Lyric video will be posted on my youtube channel today at 6PM EST ! #Z…
#
# Predicted Emoji: 🔥
#
# Text: Momma Tanya's In town ! Awesome dinner @user with friends! @ Perch
#
# Predicted Emoji: ❤
#
# Text: Thing 1 and Thing 2 @ Huron, Ohio
#
# Predicted Emoji: ❤
#
# Text: Bday girl and some random @ Sheraton New York Times Square
#
# Predicted Emoji: ❤
#
# Text: Always fun with my forever wedding date Congrats @user &amp; @user
#
# Predicted Emoji: ❤
#
# Text: La La Land @ Griffith Park Observatory-Los Angeles ,CA
#
# Predicted Emoji: ❤
#
# Text: Friends. #Seattle @ Seattle, Washington
#
# Predicted Emoji: ❤
#
# Text: #GETIT #GOTIT #GOOD #WHATEVERIWANT #BOW @ Oakland, California
#
# Predicted Emoji: ❤
#
# Text: Hanging with my bestie for the day ️#mtlove #hyalite #daysoff #fishing #endofsummer…
#
# Predicted Emoji: ❤
#
# Text: Stoked to be sitting in with @user at the @user tonight!! Therese folks are @ Great…
#
# Predicted Emoji: 🔥
#
# Text: S/O Luxe Doll @user Her YouTube review on her channel for @user will be uploaded…
#
# Predicted Emoji: ✨
#
# Text: We’re proud to be Americans #sas2017 #tpusa @ West Palm Beach,…
#
# Predicted Emoji: 🇺🇸
#
# Text: - This was gonna be my lunch for tommorow....BUT, it never made it to the refrigerator , 12…
#
# Predicted Emoji: 😂
#
# Text: Winter or summer, Chicago is pretty any time of the year... #mycity #chicago #mychicagopix…
#
# Predicted Emoji: ☀
#
# Text: Shoutout to Delores and Herbert for the drinks, bed, and good times @user @ Ottawa, Illinois
#
# Predicted Emoji: 😊
#
# Text: One of my favorite gyms FREE Fucking membership, just get your ass up . @ Balboa Park
#
# Predicted Emoji: 😎
#
# Text: Hanging with this guy today Thank you @user for the great shoot filled with plenty of…
#
# Predicted Emoji: ❤
#
# Text: mood today @ Parkway North High School
#
# Predicted Emoji: 😎
#
# Text: Chandelier @ Widener Library
#
# Predicted Emoji: 😍
#
# Text: Sorry to jump on the bandwagon. #thisfilteriseverything @ Las…
#
# Predicted Emoji: 😂
#
# Text: ️ @ Princeton, New Jersey
#
# Predicted Emoji: ❤
#
# Text: My main man @ Gladstone, Missouri
#
# Predicted Emoji: ❤
#
# Text: Eat shit Irma #ghostriotradio #hurricaneirma #irmanators #goodforsprinkle #pbr…
#
# Predicted Emoji: 😂
#
# Text: Max went on his first aquarium trip and went on a moving walkway. He did amazing! ️ Check out…
#
# Predicted Emoji: 😂
#
# Text: #ikea #fun #me ... oh this dam store, it's like disney for interior architect's @ IKEA
#
# Predicted Emoji: 😂
#
# Text: It's like I blinked and 2 years just flew by @ Short Pump Town Center
#
# Predicted Emoji: 😂
#
# Text: When moment you meet your future husband!!! @user #marlonovershawn #teammarlon @ Stress…
#
# Predicted Emoji: ❤
#
# Text: We were working so hard today @ McDonald's at 16827 Marsh Rd
#
# Predicted Emoji: 😂
#
# Text: "No Flocking" shot by @user coming soon! #LSV2 available now on #datpiff #freestyle…
#
# Predicted Emoji: 🔥
#
# Text: @user Dj Ivan G! One Mixer, One Man, One Dj, That Rocks The Party! Always with Mixes for…
#
# Predicted Emoji: 🔥
#
# Text: the only michigan state fan I can actually put up with @ University of…
#
# Predicted Emoji: 😂
#
# Text: Face of an angel... ️ #dogsofinstagram #bulldogs #pittbull #olddog #doglove #sleepingdog @user
#
# Predicted Emoji: ❤
#
# Text: At drop in's - we wear pink. #YouAreWhatYouNetflix #MeanGirls @ Beale Avenue (Beale Street)
#
# Predicted Emoji: 💕
#
# Text: i just wanna feel what I feel, when its just u and me @ Shoreline Amphitheatre At Mountain View
#
# Predicted Emoji: ❤
#
# Text: Another one from my fav spot #dtlaeveryday #canon #instamood #instagramhub #instagram…
#
# Predicted Emoji: 📸
#
# Text: Willy's point of view is...bumpy #gopro #goprosession4 #hikingwithdogs #willybob @ Lost Hills…
#
# Predicted Emoji: 📸
#
# Text: i like this movie &amp; also recommend to watch @ Amc Loews 34th…
#
# Predicted Emoji: 😂
#
# Text: Red White &amp; Boujee #doitlooklikeiwasleftoffbadandboujee @ Somewhere
#
# Predicted Emoji: 🇺🇸
#
# Text: You really are one in a Emily-on @ Copper Beech Townhomes- Morgantown
#
# Predicted Emoji: 🔥
#
# Text: {blessed} with the sisters beside me and the love between us. #hbuphimu…
#
# Predicted Emoji: ❤
#
# Text: Put Me In Coach ft @user @user coming soon #chicagotodallas @ Arlington,…
#
# Predicted Emoji: 🔥
#
# Text: 1st place in Prose Reading! @ Park Hill High School
#
# Predicted Emoji: ❤
#
# Text: Spiderman (@ Century 20 Daly City - @user in Daly City, CA)
#
# Predicted Emoji: 😍
#
# Text: Oh the weather outside is frightful but my fire ( ) is so delightful and I have no place to go,…
#
# Predicted Emoji: 🔥
#
# Text: They pulled me out of line to take this selfie... Love you both! @user
#
# Predicted Emoji: ❤
#
# Text: This guy is the real MVP @ Salt Lake City International Airport
#
# Predicted Emoji: 😂
#
# Text: Zone 1 number 1 #DisneySprings #disneysidecast #nuggetsquad @user
#
# Predicted Emoji: 🔥
#
# Text: missed them with all my ️ @ Skybar Pittsburgh
#
# Predicted Emoji: ❤
#
# Text: You a fan already Pablo X “Project LA” pt.3...#hollywood #losangeles #LA #gay…
#
# Predicted Emoji: 📸
#
# Text: Say "whale oil beef hooked" fast...sounds dirty and strangely Scottish Sorry, easily amused…
#
# Predicted Emoji: 😂
#
# Text: Found these adorable shirts in Animal Kingdom!! waltdisneyworld @ Disney's Animal Kingdom
#
# Predicted Emoji: 😍
#
# Text: Staring out into the vast spaces of the sand dunes in Colorado ️ @ Great Sand Dunes National…
#
# Predicted Emoji: 📷
#
# Text: Nothing better than -10 degrees and a hot tub @user @ Hornby, Ontario
#
# Predicted Emoji: ☀
#
# Text: When you in the hospital but you still look good . Seriously…
#
# Predicted Emoji: 😂
#
# Text: The legendary @user approves!!! #custom #couture #butchdiva #shitisreal #missionaccomplished @user
#
# Predicted Emoji: 😍
#
# Text: Where the sidewalk ends in our neighborhood. @ Chozen Dj Service
#
# Predicted Emoji: ❤
#
# Text: Quality time with Gabi Miranda! Happy Thanksgiving y’all ️#family #babygirl #love #holidays @user
#
# Predicted Emoji: ❤
#
# Text: Be original // #quotestoliveby #naplesfl #naplesflorida #uniforms #retail #embroidery…
#
# Predicted Emoji: 🔥
#
# Text: This baked macaroni is truly amazing.10 out of 10... @ Bellagio Las Vegas
#
# Predicted Emoji: 😍
#
# Text: Love our Fitfam!! #SusanGKomen #raceforthecure @ Virginia Beach…
#
# Predicted Emoji: ❤
#
# Text: Great hike today...more pics to come @ Gatlinburg, Tennessee
#
# Predicted Emoji: ❤
#
# Text: It's only fitting that I bring in my #KobeYear in LOS ANGELES! #24 @ Osteria La Buca LA
#
# Predicted Emoji: ❤
#
# Text: @ Mill Bay, British Columbia
#
# Predicted Emoji: ❤
#
# Text: Doug Gilmour ️ ️ ️ ️ ️ ️ ️ ️ ️ ️ ️ ️ ️ ️ @ Loblaws 60 Carlton
#
# Predicted Emoji: ❤
#
# Text: ★★★★★ "I love its bright colours makes me happy!! Fits perfect and well made :) Thank you!!! ️"…
#
# Predicted Emoji: ✨
#
# Text: First let me take a selfie. @ TUSKEGEE UNIVERSITY
#
# Predicted Emoji: 😂
#
# Text: Throwback Thursday My Grandson Carson diggin for Gold. @ Anna, Texas
#
# Predicted Emoji: ✨
#
# Text: Some pics, #RodeoDrive #PrettyWoman #HugeMistake #Big @ Rodeo…
#
# Predicted Emoji: 📸
#
# Text: Happy Birthday to my love bug @user Oh how I miss you…
#
# Predicted Emoji: ❤
#
# Text: #truth @ N Lakeland
#
# Predicted Emoji: 💯
#
# Text: Life Is Good. @ Loch Lomond
#
# Predicted Emoji: 😍
#
# Text: Twinning with my students today#teacherlife @ Rosenwald Dunbar Elementary School
#
# Predicted Emoji: ❤
#
# Text: @user I love you
#
# Predicted Emoji: ❤
#
# Text: HUGE FLASH SALE 45% OFF! ARC EFFECT KLETTERSACK MADE IN USA ONE DAY ONLY - CLICK LINK IN BIO…
#
# Predicted Emoji: 🇺🇸
#
# Text: @ In-N-Out Burger
#
# Predicted Emoji: 🔥
#
# Text: It's was lit tonight at the #carnbikeshow #v103 #FYB #hansleyhustle #iamlildeedee…
#
# Predicted Emoji: 🔥
#
# Text: Chickpea pasta from @user + homemade bolognese = ️. The pasta has 10 fewer carbs and 10…
#
# Predicted Emoji: 😍
#
# Text: It’s a tough #life. @ Performance Showroom at CBS Radio DFW
#
# Predicted Emoji: ❤
#
# Text: Feeling like it's going to be a good day @ Los Angeles, California
#
# Predicted Emoji: ❤
#
# Text: Haha so cute #Repost dogs.oflove (get_repost)・・・Haha Tag a friend who loves…
#
# Predicted Emoji: 😂
#
# Text: Happy 10 months to my little Peyton Rae You're so big baby girl…
#
# Predicted Emoji: ❤
#
# Text: the city that glitters @ Chicago Loop
#
# Predicted Emoji: ✨
#
# Text: That special moment when you look into your brother's eyes. ......#groom #groomsmen…
#
# Predicted Emoji: 😍
#
# Text: Wedding number one of the weekend down with my man @ Naylor Hall
#
# Predicted Emoji: ❤
#
# Text: Pulling up on Jones High today to DJ their homecoming pep rally w/ #Power953
#
# Predicted Emoji: 🔥
#
# Text: Do it for the Love, me nuh do it for the Likes #nofilter #nophotoshop @ South Beach, Miami
#
# Predicted Emoji: ❤
#
# Text: GIVEAWAY To enter to win a FREE New Years Eve dress from Fleur Fashion Boutique you must like…
#
# Predicted Emoji: ✨
#
# Text: La familia ️ @ Beaver Stadium
#
# Predicted Emoji: ❤
#
# Text: Little turkey for a #Thanksgiving gender reveal party #cute #cake #cakes #yummy @ Butter Cake…
#
# Predicted Emoji: 😍
#
# Text: Enjoying a cappy with my Mrs #norakogan #mrs #bridal #weddingring @ Sweethaus Cupcake Cafe
#
# Predicted Emoji: ❤
#
# Text: IF U ONT GOT HATERS U DOIN SOMETHIN WRONG MY G Special thanks to 1sixphotography for these fly…
#
# Predicted Emoji: 🔥
#
# Text: TPAB panel with Rapsody and Terrence Martin. (@ American Underground @ Main - @user in Durham, NC)
#
# Predicted Emoji: 🇺🇸
#
# Text: Birthday dinner with #myBride @ The Capital Grille (Raleigh, NC)
#
# Predicted Emoji: ❤
#
# Text: •Only focused on the outcomeand not stressin on our path//•Broadsideeeeee • @ Darien Lake…
#
# Predicted Emoji: ❤
#
# Text: These girls and their curls. #atlfamilyphotographer #atlantaphotographer…
#
# Predicted Emoji: 😍
#
# Text: It's gonna be a good night! What a great way to start my birthday month!! Finally I'm…
#
# Predicted Emoji: ❤
#
# Text: ️ @ Disney's Magic Kingdom
#
# Predicted Emoji: ✨
#
# Text: Chilling with my beautiful girl
#
# Predicted Emoji: ❤
#
# Text: Dinner ready - pink lipstick kinda night catch.la @ Beverly Hills, California
#
# Predicted Emoji: ✨
#
# Text: Never be alone - Shawn Mendes @user #shawnmendes #neverbealone #acousticcover #music…
#
# Predicted Emoji: 📸
#
# Text: Great night with great friends @user gabrielacalabrese…
#
# Predicted Emoji: ❤
#
# Text: #SelfieLove @ Barley's Bar
#
# Predicted Emoji: ❤
#
# Text: Sooo happy you shared this beautiful day with me! ️ ️ ️ congrats to…
#
# Predicted Emoji: ❤
#
# Text: My past 24 hours #minivacay #centralfloridazoo @ Central Florida…
#
# Predicted Emoji: ❤
#
# Text: U!S!A! Come out and enjoy taco Tuesday with Cabo and our Stars and Stripes margarita with…
#
# Predicted Emoji: 😎
#
# Text: Happy Birthday!!! @user
#
# Predicted Emoji: ❤
#
# Text: closing my Sunday off at the counter after an AMAZING brunch. #MacBoy @ MAC Cosmetics
#
# Predicted Emoji: ✨
#
# Text: It was too lit here at Tin Roof. #chicagofire #mls #tinroof…
#
# Predicted Emoji: 🔥
#
# Text: Peter Pan #PilatesStudioCity #Pilates #GroupReformer #stretchitout @ Pilates Studio City
#
# Predicted Emoji: 🔥
#
# Text: 6 1/2 is the new 9 3/4 #newyork #sixthavenue #theycallitnewyorkcity #yesterday #day4…
#
# Predicted Emoji: 😍
#
# Text: This is what I look forward to every night working tech @ David Falk Theater
#
# Predicted Emoji: ❤
#
# Text: It's international day of the girl? Here's to being super.... #dayofthegirl…
#
# Predicted Emoji: ❤
#
# Text: When a suicide is on the line just call me "Mr. Clutch" I told the campers it's money!…
#
# Predicted Emoji: 😂
#
# Text: Love these guys! @ Town of Highlands, NC, US
#
# Predicted Emoji: ❤
#
# Text: @ Buffalo Wild Wings
#
# Predicted Emoji: ❤
#
# Text: SHOP Montrose! NOW and at the CAR SHOW this Sunday 9-2 @ Montrose Shopping Park Association
#
# Predicted Emoji: 🎄
#
# Text: Class act @ H2O International Ocean City, MD
#
# Predicted Emoji: 😎
#
# Text: My foinnnneee lady! ️ ️ ️ dang, she is gorgeous! @ The White House
#
# Predicted Emoji: 😍
#
# Text: Rehearsing Così finale over the phone..... (I took the delay )But…
#
# Predicted Emoji: 😂
#
# Text: She is my bigs best friend so she is my big @ Doyt Perry Stadium
#
# Predicted Emoji: ❤
#
# Text: Let's go a Opening! #pfreddy #darkmagic #wilsonphillips #itslit? @ Prince Frederick Hall
#
# Predicted Emoji: ✨
#
# Text: We play well together #throttletwisting #strongertogether…
#
# Predicted Emoji: ❤
#
# Text: Like it? Hit the " ️" or double tap . Credit to all respective owners . . . .. .…
#
# Predicted Emoji: 😂
#
# Text: The kids are gonna be (at @user in Seattle, WA)
#
# Predicted Emoji: 😂
#
# Text: Live in the moment, @ South Beach, Miami
#
# Predicted Emoji: ❤
#
# Text: Just a spring break mirror selfie @ Hoover, Alabama
#
# Predicted Emoji: 📸
#
# Text: Hanging out &amp; duty driver today @ Pippin Hill Farm &amp; Vineyards
#
# Predicted Emoji: 😂
#
# Text: Just do what makes you happy #misniños #losAmo ️ @ Rockport Beach
#
# Predicted Emoji: ❤
#
# Text: Tory Burch (brand new!) @ Twinkle Resale Boutique
#
# Predicted Emoji: ✨
#
# Text: Before @user did their amazing makeover in #nyc. My girls living it up…
#
# Predicted Emoji: 😍
#
# Text: we just came for the cookies and sparklers @ Puyallup, Washington
#
# Predicted Emoji: 🎄
#
# Text: Hello 2018 en Inn of the Mountain Gods
#
# Predicted Emoji: ✨
#
# Text: ️ LOVE THIS! #GirlPower #Grateful @ Irving, Texas
#
# Predicted Emoji: ❤
#
# Text: When you arrive to your client's home before them so you take a little break poolside …
#
# Predicted Emoji: ❤
#
# Text: Missing a nice walk on the San Fran’s hills Gratitude can transform common days into…
#
# Predicted Emoji: ☀
#
# Text: @ Jacks Bar Pittsburgh
#
# Predicted Emoji: ❤
#
# Text: Happy Birthday, Aunt Tee! So good to see you! @ Rooster's Kitchen
#
# Predicted Emoji: ❤
#
# Text: CUBAN COPY famous Bundles are here!! #cubancrafters…
#
# Predicted Emoji: 🔥
#
# Text: Go To @user And Get My New Tape #HotBoyMusicVol2 Out Now!!!! For Exclusive Music Follow…
#
# Predicted Emoji: 🔥
#
# Text: Favorite place I get to visit a couple times a year. #otherwildanimals @ Cornwallville, New York
#
# Predicted Emoji: ❤
#
# Text: Jads Cash and The Southern Trio! I Was there when it happened.#johnnyCash #JadsCash…
#
# Predicted Emoji: 😂
#
# Text: Wish trip 2017! Disney ️ #givekidstheworld #gktw #maw #epic…
#
# Predicted Emoji: ✨
#
# Text: Love my mommy #madrebro #bestfriend @ San Diego, California
#
# Predicted Emoji: ❤
#
# Text: Tonight Sunday 9/4 @user #LaborDayWeekend2016 2/$300 Belaire, Ciroc, Goose,…
#
# Predicted Emoji: 🔥
#
# Text: we finally made it &amp; I can't wait to see what KSU has in store for us @ WSU/Koch Arena
#
# Predicted Emoji: ❤
#
# Text: I love you. Happy Birthday. @ Phipps Plaza
#
# Predicted Emoji: ❤
#
# Text: I'll be on the #road headed to #Moab #Utah next week! Can't wait to #run and have #fun! @ Fisher…
#
# Predicted Emoji: 😂
#
# Text: And thats a wrap!!!! Getting ready to get back to the grind ...#paintcabin #tapeart…
#
# Predicted Emoji: 😎
#
# Text: she though the campus was pretty but i thought she was prettier @user
#
# Predicted Emoji: 😍
#
# Text: Sunset #mayflowerbeach #beach #sunset #nofilter @ Ocean Vista Cape Cod, Ma
#
# Predicted Emoji: 😍
#
# Text: Happy 4th and beware of temptation, things aren't always what…
#
# Predicted Emoji: 🇺🇸
#
# Text: Color: Red, Blue or Green. Distance: Sprint, Super or Beast.All 3? Trifecta! …
#
# Predicted Emoji: 💙
#
# Text: 8:12pm8:32pm#nofilter #moonlight ️ @ Hilton Head Island Beach &amp; Tennis Resort, Inc.
#
# Predicted Emoji: ✨
#
# Text: Made a little friend at the Kris Kringle fair #reallifenativity#kriskringle #donkey…
#
# Predicted Emoji: ❤
#
# Text: 2 cats and a pimp @ Copper Beech Townhomes - Greenville, NC
#
# Predicted Emoji: 😂
#
# Text: About to see Shape of Water with my bestie
#
# Predicted Emoji: ❤
#
# Text: Happiest birthday wish to my #selfie #queen and #bff Love you long time and can't wait to…
#
# Predicted Emoji: ❤
#
# Text: #tbt #CaliforniaDreaming @ The Beverly Hilton
#
# Predicted Emoji: 😍
#
# Text: #CesarYahirNunez @ Los Angeles Auto Show
#
# Predicted Emoji: ❤
#
# Text: A maltipoo, a sleeping baby and a @user margarita = . @ Southampton , New York
#
# Predicted Emoji: 😂
#
# Text: Huge thanks to my boy for making my birthday weekend the BEST &amp; for…
#
# Predicted Emoji: ❤
#
# Text: 30 min KB circuit. Killed my glutes and shoulders Feeling good. Feeling accomplished.We…
#
# Predicted Emoji: 😂
#
# Text: #'s don't lie djrakuttz@youtube.com #pressplay Dj for the #GrownandSexy #MatureandSure…
#
# Predicted Emoji: 🔥
#
# Text: ️Perfect verse in my devotional this morning! ️God's promises are…
#
# Predicted Emoji: ❤
#
# Text: You in first place @ Medusa restaurant &amp; lounge
#
# Predicted Emoji: 🔥
#
# Text: ️ we've been together a whole year now ️ @ Atlanta, Georgia
#
# Predicted Emoji: ❤
#
# Text: Merry Christmas from Lilly and I. #art #lillybugart #livingroom #photo #painting #pobjecky…
#
# Predicted Emoji: 🎄
#
# Text: #abundance #vibrations #believe #thelawofattraction #mondaymantra @ Los Angeles, California
#
# Predicted Emoji: ✨
#
# Text: i miss you @user @ Quicken Loans Arena
#
# Predicted Emoji: ❤
#
# Text: So much eye candy @user @user nyfw @user @user
#
# Predicted Emoji: 😍
#
# Text: The last troopers left standing! We are on a prowl to find the next hot spot #bridalparty with…
#
# Predicted Emoji: 🔥
#
# Text: Dressed up for core @ CORE Lifestyle and Recreation Complex
#
# Predicted Emoji: 😂
#
# Text: Fall coming through Ruffle sleeve top available for {$18} Comes in S,M,L @ Blue's Fashion…
#
# Predicted Emoji: 📸
#
# Text: Had to make that run earlier @user pizza is the best @user
#
# Predicted Emoji: 😂
#
# Text: Look at her amount of growth in only 7 months! And it continues to grow I used #SilkShampoo &amp;…
#
# Predicted Emoji: ❤
#
# Text: This girl right here! #love #daddysgirl @ Crocker Park
#
# Predicted Emoji: ❤
#
# Text: Holidays on the sound. Cuppa coffee, yogurt and my . What more could a girl ask for?…
#
# Predicted Emoji: 🎄
#
# Text: Oh yeah! This is how I like to arrive #home #portland #pdx #imhome #airbnb #rainydays…
#
# Predicted Emoji: 😍
#
# Text: #grilling #firebuilt #firepit #firetonight -#elmgrove @ Elm Grove, Wisconsin
#
# Predicted Emoji: 🔥
#
# Text: 12.4.17Congratulations to Queen Lanie love I’m seriously so proud of my girl. She has a…
#
# Predicted Emoji: ❤
#
# Text: I love u Amora. My heartbeat. #lovedones ️ #lovebugs #lovebugg #amoramor #babys #daughter…
#
# Predicted Emoji: ❤
#
# Text: Mom. #WeLookGood @ UNT Coliseum
#
# Predicted Emoji: ❤
#
# Text: No filter needed on this handsome boy #belgianhorse #middletonplace #perfectsunday @ Middleton…
#
# Predicted Emoji: 😍
#
# Text: @ Hilton Head Island, South Carolina
#
# Predicted Emoji: ❤
#
# Text: dreams do come true @ Disney's Magic Kingdom
#
# Predicted Emoji: ✨
#
# Text: Colorguard Show loara High School @ Loara High School
#
# Predicted Emoji: ❤
#
# Text: Woo, Woo, Woo! Our Saturday line-up is on FIRE! The 29th Annual Long Beach Jazz Festival…
#
# Predicted Emoji: 🔥
#
# Text: @user do #ldnont (day 1 ) @ Abruzzi
#
# Predicted Emoji: 😂
#
# Text: Disney days are my favorite days @ Disneyland
#
# Predicted Emoji: ✨
#
# Text: #TransformationalCoffee ice cream floats anyone?! .Now on tap at manhattanbeachcreamery…
#
# Predicted Emoji: 😍
#
# Text: This logo right here means a lot to me.. it'll mean something to…
#
# Predicted Emoji: 😂
#
# Text: Extra happy cuz mom just lost Dodger trivia &amp; had to buy us all icecream #FAM @ Dodger Stadium
#
# Predicted Emoji: ❤
#
# Text: Hanging out at the Rocky’s #nobigdeal #wholemetravels #travelwithwholeme⠀------- : @user @user
#
# Predicted Emoji: 📸
#
# Text: Happy Saturday Caroline, Job and Greg!!! @user @user @user
#
# Predicted Emoji: ❤
#
# Text: Saturday's are for sipping champagne (we only spray on Sunday's ). Join us for a tropical…
#
# Predicted Emoji: ✨
#
# Text: Happy Birthday my Love!#iloveyou #foreverandalways #my #28…
#
# Predicted Emoji: ❤
#
# Text: ️ @ Main Street, U.S.A.
#
# Predicted Emoji: ❤
#
# Text: Going to a wedding, event or just want to #werk a great blow dry this weekend? This Friday…
#
# Predicted Emoji: 😂
#
# Text: Photo creds to @user #KeepTahoeBlue #LaborDay @ Sand…
#
# Predicted Emoji: 📸
#
# Text: Family is forever @ Abdalian Home
#
# Predicted Emoji: ❤
#
# Text: Cleaned up with our Outdoor soap and enjoying a and a beer! organic #photooftheday…
#
# Predicted Emoji: 😊
#
# Text: Missing my favorite dancer in Hollywood, @user Kuya, you still need to teach me how to do…
#
# Predicted Emoji: ❤
#
# Text: Lol True #goheavyorgohome #muscle @ Neil Burns Fitness Center
#
# Predicted Emoji: 😂
#
# Text: This one was for you DJ ️ out of everything I’ve learned from this…
#
# Predicted Emoji: 🔥
#
# Text: Love this man beyond words. #loveofmylife #chicago #skyline #cityscape #windycitywonders @user
#
# Predicted Emoji: ❤
#
# Text: # @ Lin's Grand Buffet
#
# Predicted Emoji: 😍
#
# Text: We put the girl in charge of the fire tonight and she's very proud of her work #campfire…
#
# Predicted Emoji: 🔥
#
# Text: On my way to happy hour Skirt &amp; Bag by ysl Shoes by @user Socks by @user Jewelry…
#
# Predicted Emoji: 📸
#
# Text: ️ (@ Library of Congress - @user in Washington, DC)
#
# Predicted Emoji: 🇺🇸
#
# Text: Tonight will be LIT!!! Can't leave Miami without checking stopping by CLUB BOI @user
#
# Predicted Emoji: 🔥
#
# Text: Now there is no other option but to succeed. It's written in blood. ️ @ Texas
#
# Predicted Emoji: ❤
#
# Text: #mondaymood with @user wearing @user tees #coworkers #thewhiskeylifestyle @ Marvel…
#
# Predicted Emoji: 😂
#
# Text: Revoked my handicap sticker. Sorry Stevie #ICanSee @ AVA NoHo
#
# Predicted Emoji: 😂
#
# Text: And we celebrate @ Waner Ball Park
#
# Predicted Emoji: ❤
#
# Text: @user flying as he always seems to be. #UnadillaMX @ Unadilla Motocross
#
# Predicted Emoji: 😂
#
# Text: Throwback to over a year ago.. lammiglass Photo cred: fotopoesia2015 Tan by:…
#
# Predicted Emoji: 📸
#
# Text: #myself thank you miusok for that @ Manhattan, New York
#
# Predicted Emoji: ❤
#
# Text: This is #PureMichigan... ready to go back already... ....#LakeLife #Michigan…
#
# Predicted Emoji: 🔥
#
# Text: Happy
#
# Predicted Emoji: ❤
#
# Text: We at @user THIS FRIDAY NIGHT, opening for gavinturek! Slide thruuuu!!! @ The New Parish
#
# Predicted Emoji: 📸
#
# Text: Soul summit party in Ft Greene park We lit right now @ Summer Soul Ft Green Park
#
# Predicted Emoji: 🔥
#
# Text: Beer, BBQ &amp; Bocce Ball ...#food #foodporn #instafood #foodie #foodpic #foodpics #foodgasm…
#
# Predicted Emoji: 😍
#
# Text: Cute baby Tyson @ Nashville, Tennessee
#
# Predicted Emoji: ❤
#
# Text: Sunset + Weekend = #mohegansun #hotsummerfun #weekendvibes @ Mohegan Sun
#
# Predicted Emoji: ☀
#
# Text: Had such an awesome girls day out with my sisters fuicafresh4 &amp; tiffany! #Bibimbap #koreanfood…
#
# Predicted Emoji: ❤
#
# Text: these fucking Steve Harvey / miss universe memes are killin me
#
# Predicted Emoji: 😂
#
# Text: ya might not make me look skinny, but ya make me look tan @ North…
#
# Predicted Emoji: 😎
#
# Text: Let's just say, golf doesn't run in the family @ Maple Lane Golf…
#
# Predicted Emoji: ❤
#
# Text: So this happened this afternoon @ Ulta Beauty
#
# Predicted Emoji: 😍
#
# Text: Snow shoot Dec 2016, pt. 1Model: chiallicat : #Nikon D100 w/ #Sigma 70-300mm(This post was…
#
# Predicted Emoji: 📸
#
# Text: The love of my life! @ Deck 84
#
# Predicted Emoji: ❤
#
# Text: And make sure you Have Some Fun Today #hsftofficial @ SoulCycle
#
# Predicted Emoji: ❤
#
# Text: How #gorgeous are these Luxe Liquid #Lipsticks from timelosangeles? They go on very #creamy…
#
# Predicted Emoji: 😍
#
# Text: on it's way @ Camba Mosquito Brook Trail Head
#
# Predicted Emoji: 📸
#
# Text: Some Friday for ya - Carbon Aeolus 3 TLR disc wheel rockin' a Challenge Chicane 300 TPI open…
#
# Predicted Emoji: 🔥
#
# Text: It's a privilege to help my clients buy or sell a home. #mdavisrealestate #marshallrealty…
#
# Predicted Emoji: ❤
#
# Text: Happy 4th America #friends #unitedstates #independenceday…
#
# Predicted Emoji: 🇺🇸
#
# Text: Getting Momma out for a walk! She is healing like a champ ...#winterinwisconsin…
#
# Predicted Emoji: ❤
#
# Text: regram@BiggShotsModeling missrosielySometimes it's as clear as blk&amp;wht.@bellusmagazine…
#
# Predicted Emoji: 🔥
#
# Text: One of the highlights at this #miku10th rave party, fckn T-Rex raving with glow sticks …
#
# Predicted Emoji: ✨
#
# Text: Taught my kids the mantra early. jk Isaiah wants to be an actor and he saw this somewhere and…
#
# Predicted Emoji: 😂
#
# Text: @ Notre Dame Stadium
#
# Predicted Emoji: ❤
#
# Text: Fun photoshoot today thank you lexikleyla &amp; @user for putting me together loved it! @user
#
# Predicted Emoji: ❤
#
# Text: Anyone for a drive thru daiquiri? #roadtrippin #badidea #wtf @user
#
# Predicted Emoji: 😂
#
# Text: A new day to start something good have a nice civic day folks ! @ City of Windsor
#
# Predicted Emoji: 😎
#
# Text: Smoothie prep, ready to freeze ...#summer #fresh #smoothie #foodie #foodprep #banana…
#
# Predicted Emoji: ☀
#
# Text: Everyday is a great day when you're a buckeye #9daystilkickoff @ The Shoe, the Ohio State…
#
# Predicted Emoji: 🇺🇸
#
# Text: anything goes on a friday night @ Florida Georgia Line w/ Nelly at Coastal Credit Union Music…
#
# Predicted Emoji: 📸
#
# Text: Another great night with the girls! @ Croxley Ale House…
#
# Predicted Emoji: ❤
#
# Text: Louisville's largest cinnamon roll! @ Louisville, Kentucky
#
# Predicted Emoji: ❤
#
# Text: God bless @ Newspring Church Clemson Campus
#
# Predicted Emoji: ❤
#
# Text: Great saying from #AlbertEinstein #realstory #fact #Mrnofilters #GilbertFonticoba…
#
# Predicted Emoji: 😂
#
# Text: im just #Spears today... #i ATL @ Waffle House
#
# Predicted Emoji: ❤
#
# Text: Yall Ready !!?? I Aint Gotta Say Too Much, Pull Up On Me For Chief Keef Tickets Hosted By Lil…
#
# Predicted Emoji: 🔥
#
# Text: Aghhh is this real life? #unveileweddingsandevents #sandcreekcountryclub #countryclubweddings…
#
# Predicted Emoji: 😂
#
# Text: "@wnderlustvibes: Lets travel together @user
#
# Predicted Emoji: 😂
#
# Text: Yoga 9:45-10:45, plus a little work out (at @user in Fort Myers, FL)
#
# Predicted Emoji: ✨
#
# Text: And another photo shoot moment. I introduced Kristin to the "Portrait" mode on her phone. …
#
# Predicted Emoji: 📸
#
# Text: Too much sauce @ Manny's On Second
#
# Predicted Emoji: 🔥
#
# Text: BLUES WIN!!!! #stlblues #letsgoblues #lgb #stlouisblues #birthdaypresent #weallbleedblue @user
#
# Predicted Emoji: ❤
#
# Text: Thanks Hollywood, FL See you very soon Clearwater, FL!#aussiefloyd #australianpinkfloyd @user
#
# Predicted Emoji: ❤
#
# Text: Can't wait to be back home with my slices @ M&amp;M World, Times Square, New York City
#
# Predicted Emoji: 🇺🇸
#
# Text: Oh we got Effens too! Last nights set up Wedding Flow!! #Kenny&amp;Betsy #Toons #toonsquad…
#
# Predicted Emoji: ❤
#
# Text: "Maybe God just kinda likes, Cowboys and Angels" #wcw #wce @user @user @ Boylan…
#
# Predicted Emoji: 😂
#
# Text: Another win! Great job mighty mights ️12-6 @ PPO Football
#
# Predicted Emoji: ❤
#
# Text: Lmao that last retweet is SO me
#
# Predicted Emoji: 😂
#
# Text: bluedotband just brought smiles to everyone’s faces with this colourful number #sofarsounds…
#
# Predicted Emoji: 😊
#
# Text: I lock cocktails and bread almost as much as these ladies @user
#
# Predicted Emoji: ❤
#
# Text: All I need is my big by my side @ World of Beer (University Plaza-…
#
# Predicted Emoji: ❤
#
# Text: Homecoming #available #homecoming2k17 #emu20 #emu19 #emu18 #emu21 #teamemu #truemu…
#
# Predicted Emoji: ❤
#
# Text: Beautiful Brunette with rich golden highlights #christopherstephenssalon #palmbeach #salon #spa…
#
# Predicted Emoji: 😍
#
# Text: Big Chop for Wigs For Kids Foundation alicia_hair#naturallyuniquesalonokc #okcstylist…
#
# Predicted Emoji: ✨
#
# Text: Last selfie with udre_anna... For at least a couple months. We hope. Tomorrow, she goes home…
#
# Predicted Emoji: ❤
#
# Text: Travel and Learn but don't forget to also have some fun while you're doing that …
#
# Predicted Emoji: 😂
#
# Text: My sleepy pup @ Teal Run Apartments
#
# Predicted Emoji: ❤
#
# Text: I hope you have a wonderful first day of school go out there and do big things with your life…
#
# Predicted Emoji: ❤
#
# Text: People wonder why I do this weekly #AnotherOne #GetAtRyGuy @user
#
# Predicted Emoji: 😂
#
# Text: Fridays are #catsofinstagram @ Bowling Green, Ohio
#
# Predicted Emoji: 🔥
#
# Text: Showcase @ Fierce All-Stars
#
# Predicted Emoji: ✨
#
# Text: Alesia Cara concert with this cutie pie!! Xox ️ @ Caesars Windsor
#
# Predicted Emoji: ❤
#
# Text: Was a good 4th of July!! #4thofjuly #california #sanfrancisco #emeraldlake…
#
# Predicted Emoji: 🇺🇸
#
# Text: grease is the word @ Sigma Alpha Mu West Virginia University
#
# Predicted Emoji: 🔥
#
# Text: She's alright @ Appoquinimink High School
#
# Predicted Emoji: 😎
#
# Text: L.E.D Marina project michrotech #energy #eco #led #poles #projectmanagement @ Ft Lauderdale Beach
#
# Predicted Emoji: ✨
#
# Text: Repost from my Lil bro @user Don't Be That Nigga …
#
# Predicted Emoji: 💯
#
# Text: Thanks for coming back from Spain @ Beech Street, Oxford Ohio
#
# Predicted Emoji: ❤
#
# Text: I haven't been excited about Friday, since last Friday! ...#friday #fridaymood…
#
# Predicted Emoji: ✨
#
# Text: Thanks so much for letting me tag along for Labor Day/ bachelorette weekend!! ️ @ Seagrove…
#
# Predicted Emoji: ❤
#
# Text: I was told that if I get fired from my day job, I can always take up chalkboard art. Yesterday…
#
# Predicted Emoji: 😂
#
# Text: The julievinobridal 2018 Havana Collection is perfection! Join is for our exclusive Julie Vino…
#
# Predicted Emoji: ✨
#
# Text: Constantly treating herself (@ The @user Factory in Chestnut Hill, MA)
#
# Predicted Emoji: 😍
#
# Text: This picture makes me proud to be American , grab the wheel and chase those dreams.…
#
# Predicted Emoji: 🇺🇸
#
# Text: #tvhexperience @user @ Designz by Tiana Renee
#
# Predicted Emoji: 📸
#
# Text: So happy I was able to spend some time with my besties! Best friends since high school #ooony…
#
# Predicted Emoji: ❤
#
# Text: Doggie selfie #nofilter @ Topper home , Reno/Tahoe,NV
#
# Predicted Emoji: 📸
#
# Text: Me and the girls @ Glens Falls, New York
#
# Predicted Emoji: ❤
#
# Text: this beautiful soul rode three hours to come watch me cheer and I love her so much for that …
#
# Predicted Emoji: ❤
#
# Text: You guys brunchin’ today?Pictured: Bagels &amp; Loc for 3 at @user #brunchokc #okc #brunch…
#
# Predicted Emoji: ❤
#
# Text: Religious jewelry #jewelry#crosses #religious #rosaryring #gold#silver #religiousjewelry @user
#
# Predicted Emoji: ✨
#
# Text: More missiles flew today.. @user And I letting off ICBM's lol . A g Speed dropped a bit…
#
# Predicted Emoji: 😂
#
# Text: Forgiveness is a big part of our #happyhealthymind!! @ Hello Dinner
#
# Predicted Emoji: ❤
#
# Text: Day 6: Half Moon | Word: Country Hosts: @user hollapop,…
#
# Predicted Emoji: ❤
#
# Text: One of my best experiences that I learned today Captin…
#
# Predicted Emoji: ❤
#
# Text: That part! @ Shreveport, Louisiana
#
# Predicted Emoji: 😂
#
# Text: When you brunch with your grandmas &amp; sisters @ Soho House West Hollywood
#
# Predicted Emoji: ❤
#
# Text: right before champagne was drank &amp; tables were danced on …
#
# Predicted Emoji: 🔥
#
# Text: WEST COAST ludogrillo @ The Cosmopolitan of Las Vegas
#
# Predicted Emoji: ❤
#
# Text: We've even got #thebeat pencil fights here at Walk On's!! 1400 Pantheon Way we're having a good…
#
# Predicted Emoji: 😂
#
# Text: TONIGHT! #holdinon #AllSix #woodswig #bobsshorts #theonlyBostonteamiveeveracknowledged…
#
# Predicted Emoji: 🔥
#
# Text: She's summer ready #hairbyrosapinto #hairofinstagram #hairoftheday #hairfashion…
#
# Predicted Emoji: 🔥
#
# Text: This little monster!!!! He is so stinkin' cute and #auntybrooke loves him so much! #derbys…
#
# Predicted Emoji: 😍
#
# Text: ️ ️ ️ #truth @ Hill East
#
# Predicted Emoji: 💯
#
# Text: AvailablePrice $ 5.00 plus tax and shippingRemember, it has no lead and nickelAll shipped…
#
# Predicted Emoji: ❤
#
# Text: Well - crossing the street is my new favorite #insta_chicago #statestreet #OnAstRoll @ State…
#
# Predicted Emoji: ❤
#
# Text: Q was meant to be a boss and that she shall be. I am that I am
#
# Predicted Emoji: 😂
#
# Text: ona mission. @ Hollywood Boulevard
#
# Predicted Emoji: ❤
#
# Text: State Fair!! Michael and Arielle's first time!! (@ 2017 State Fair of Texas)
#
# Predicted Emoji: 🇺🇸
#
# Text: I can't believe I was on the set of ncisnola . Watching the cast stream off of the set, and…
#
# Predicted Emoji: 🔥
#
# Text: Happy Thanksgiving . A visit to Hollywood Hall of Fame in pictures…
#
# Predicted Emoji: ❤
#
# Text: Today was a great day. Happy Birthday Viktor Now the birthday countdown to Christian's 18th…
#
# Predicted Emoji: ❤
#
# Text: Ready to take on the afternoon. @ Palm Springs, California
#
# Predicted Emoji: ☀
#
# Text: Mom ur awesome #beatthesteelers @ M&amp;T Bank Stadium
#
# Predicted Emoji: ❤
#
# Text: Sunday desserts with my sweets. ️ ️#brewtea…
#
# Predicted Emoji: 😍
#
# Text: Thanks for always being my wedding date @ Virginia
#
# Predicted Emoji: ❤
#
# Text: Good Morning 'Merica I AM BACK AND FULLY RECHARGED! My winter vacations were better than I…
#
# Predicted Emoji: ☀
#
# Text: Ketel One feels ........#DiageoRep #ketelone #vodka #tastetest #oranje #citroen…
#
# Predicted Emoji: ❤
#
# Text: we our job almost as much as we each other :) come to scoop du…
#
# Predicted Emoji: ❤
#
# Text: @ Oracle Arena and Coliseum
#
# Predicted Emoji: 🔥
#
# Text: Morning, NYC! ....#concretejungle #newyork #nyc #actresslife #actress @ 25th Street…
#
# Predicted Emoji: ❤
#
# Text: Here lie the victim of a #Crossfit #herowod R.I.P. Corporal…
#
# Predicted Emoji: 😂
#
# Text: #WCW because I miss you and I miss ACL @ Austin City Limits Music Festival (ACL)
#
# Predicted Emoji: ❤
#
# Text: We have been waiting for this moment for years! Welcome to Corpus, @user @ Jimmy Johns…
#
# Predicted Emoji: ❤
#
# Text: Happy 4th! #america @ Indiana
#
# Predicted Emoji: 🇺🇸
#
# Text: 26 never looked so good #midorianfling #mare #jumper #hunter @ Regal View Stables
#
# Predicted Emoji: 😍
#
# Text: @user Awww thank you!! I was excited to discover it! #pottermore #PottermorePatronus
#
# Predicted Emoji: ❤
#
# Text: Thanks for your help @user #bestcustomerservice #hedressesDak #nowlittlemark @user
#
# Predicted Emoji: ❤
#
# Text: Can I go back?!?!! Loved every minute of this trip #PCB #nofilter @ Panama City Beach, Florida
#
# Predicted Emoji: ☀
#
# Text: Hangout with my amazing girlfriend husband @user joster0802 #Jia the best couple in the…
#
# Predicted Emoji: ❤
#
# Text: THis Wednesday 4/20 we goin set the Town on we at @user w/ @user
#
# Predicted Emoji: 🔥
#
# Text: Bride Tribe #thenightbefore @ Willard InterContinental
#
# Predicted Emoji: ❤
#
# Text: ️ @ Epcot - Walt Disney World
#
# Predicted Emoji: ❤
#
# Text: (@ Apple Millenia in Orlando, FL)
#
# Predicted Emoji: 😍
#
# Text: Beautiful ️ ️ ️ @ On Lake Mohawk
#
# Predicted Emoji: 😍
#
# Text: Perks of living near a major interstate #GoArmy #Sarge @ Elko, Nevada
#
# Predicted Emoji: 😂
#
# Text: IM SO CONTENT W MY LIFE ATM
#
# Predicted Emoji: ❤
#
# Text: Finally found another shot of me from ComicCon!!!! Photography by infamousganjo #batman…
#
# Predicted Emoji: 📸
#
# Text: Start x Marshall #fender #stratocaster #marshallamps #guitarist #riffwars #guitars #dtla…
#
# Predicted Emoji: 📸
#
# Text: Even the devil was once an angel ️ @ Kent State University
#
# Predicted Emoji: 💙
#
# Text: #jedi tutu guy also known as @user yiiip we nerdy big kids that love@playing with toys…
#
# Predicted Emoji: 😂
#
# Text: Washington Monument's got by back. @ Washington Monument National Monument
#
# Predicted Emoji: 🇺🇸
#
# Text: Hillclimb fun ..dirthammers klimmotorcycle @user senabluetooth @user xcgear17…
#
# Predicted Emoji: ❤
#
# Text: Geez how'd I get so lucky @ Florence, Alabama
#
# Predicted Emoji: 😍
#
# Text: Happy Birthday BreG!! Throwback to greatest photo ever taken at COBA! Hope ya have good one!…
#
# Predicted Emoji: ❤
#
# Text: Bye ciao #ciao #bye #plane #nyc #wanderlust #jetblue @user thank you @ Newark Liberty…
#
# Predicted Emoji: 😘
#
# Text: Graduating with Minnie and Mickey @ Disney's California Adventure Theme Park
#
# Predicted Emoji: ❤
#
# Text: When all is said and done...#homesweethome @ Grant Park, Atlanta
#
# Predicted Emoji: 😂
#
# Text: Flipping Blackberry #thelobbydenver #denver #colorado #mixology #mixologist #travelblogger…
#
# Predicted Emoji: 😂
#
# Text: It's not thanksgiving for another month but wow I'm thankful for these next few weekends
#
# Predicted Emoji: ❤
#
# Text: Making money is my number one hobby , the secret between the rich and poor is that the rich took…
#
# Predicted Emoji: 😂
#
# Text: New video posted #bodybuilding #bulk #bodybuilder…
#
# Predicted Emoji: 📸
#
# Text: Number 1 if I HAVE to pick, but I'd love to drive them all ...#porsche #porsche911…
#
# Predicted Emoji: ❤
#
# Text: I really like this one. #zebralover #757 #norfolkzoo #zebras @ Virginia Zoological Park
#
# Predicted Emoji: 😂
#
# Text: #drake#future#summersixteentour#summersixteentour @ United Center
#
# Predicted Emoji: ❤
#
# Text: My sweet lunch companions @ The Kitchen
#
# Predicted Emoji: ❤
#
# Text: #NuffRespect #JohnDodgingBullets funniest shit ever @ South Side, Mount Vernon
#
# Predicted Emoji: 😂
#
# Text: Back to the grind @ Pinellas County, Florida
#
# Predicted Emoji: 💯
#
# Text: Night time view @ Grand Hyatt San Diego
#
# Predicted Emoji: ✨
#
# Text: Presenting these beauties from @user for a client library this morning. Love #JDEI…
#
# Predicted Emoji: ❤
#
# Text: Good MORNIN SUNSHINEEEE @ Kissin' and the Crickets is the Only…
#
# Predicted Emoji: ☀
#
# Text: Living a life of accepting and giving forgiveness is living a life of joy. #accepting #forgiveness #joy
#
# Predicted Emoji: ✨
#
# Text: That lighting tho @ Buffalo Wild Wings
#
# Predicted Emoji: 😂
#
# Text: @ Lake Gregory Regional Park
#
# Predicted Emoji: 📷
#
# Text: #labordayweekend2016 @ Sugar Factory Orlando
#
# Predicted Emoji: ❤
#
# Text: The office calendar for this year! #myofficelife #catsofinstagram @ Allen Community College
#
# Predicted Emoji: 🎄
#
# Text: regranned from @user - AYYYYYYYEEEEEEE Y'all check out the official video…
#
# Predicted Emoji: 📸
#
# Text: Obsessed with my new Delta Gamma hat from @user Shop online at
#
# Predicted Emoji: 😍
#
# Text: Happy Veterans Day! #thankyou #oldschoolURI #uristudentaffairs @ University of Rhode Island
#
# Predicted Emoji: 🇺🇸
#
# Text: ZGOC Holiday party... hanging with one of my ️! We have similar…
#
# Predicted Emoji: 🎄
#
# Text: Our first time at a cidery! Beautiful day for it too ️ @ Corcoran Vineyards
#
# Predicted Emoji: 😍
#
# Text: @ Tha Queen's Dome
#
# Predicted Emoji: ❤
#
# Text: Vote Clinton/Ka[i]ne on Tuesday, it's the one way forward for @ Brooklyn, New York
#
# Predicted Emoji: 🇺🇸
#
# Text: Throw back with the real squad of Blytheville @ Bly-Vegas
#
# Predicted Emoji: 💯
#
# Text: @user sunset... @user #beachbar @ Beach
#
# Predicted Emoji: ❤
#
# Text: My Grandparents they were HUGE role models in my life, especially my grandpa. He taught me how…
#
# Predicted Emoji: ❤
#
# Text: 90 minute flight to Ohio but the suspense is killing me!! #Onthelist #travel americanair @ PHL…
#
# Predicted Emoji: 😂
#
# Text: This wasp nest is so damn gorgeous ... I can't help but think these bastards contributed to our…
#
# Predicted Emoji: 😍
#
# Text: Feeling myself @ Apostolic Faith Mission
#
# Predicted Emoji: ✨
#
# Text: 20 g of Protein in this carrot cake! Low carb/fat and no sugar added @user is now at…
#
# Predicted Emoji: 🔥
#
# Text: #pixelforest #mfah @ The Museum of Fine Arts, Houston
#
# Predicted Emoji: 📸
#
# Text: I got my Pi Kapp little last night and I am OBSESSED!!! @ Pi…
#
# Predicted Emoji: ❤
#
# Text: Dinner, Coasters, and Dessert with these two beauties! #greatnightout #batmantheridetwice…
#
# Predicted Emoji: ❤
#
# Text: Representing at Epcot yesterday. @ Epcot - Walt Disney World
#
# Predicted Emoji: ✨
#
# Text: she desperately wanted to go with me to #greatmex --love you Lucia ️ @ Great Mex Balboa
#
# Predicted Emoji: ❤
#
# Text: New discwomannyc merch alert! Support your real friends. @ Bushwick, Brooklyn
#
# Predicted Emoji: 🔥
#
# Text: Periwinkle power couple @ North Ridge Country Club
#
# Predicted Emoji: ❤
#
# Text: This is what I'm talking about! It's always a good thing to have a #chef for a friend …
#
# Predicted Emoji: 😂
#
# Text: Never go old for the Disney store @ Disney store
#
# Predicted Emoji: ✨
#
# Text: I've had so much fun this summer with these kids! @ CGA - Cabot…
#
# Predicted Emoji: ❤
#
# Text: Don't forget to bring a towel : jameslharper @ Metro Gallery
#
# Predicted Emoji: 📸
#
# Text: A little fun with the team tonight ️ Have you heard about the LimeLight opportunity? Click link…
#
# Predicted Emoji: ✨
#
# Text: I love ice cream and I love Christmas lights. #icecream #christmas #florida #vacation…
#
# Predicted Emoji: 🎄
#
# Text: Rings from the Old West and the New York. #turquois stonesparrow #hopi #americana…
#
# Predicted Emoji: ❤
#
# Text: couldn't ask for a better group of friends . ️ #AssBlasters @ Decatur Central High School
#
# Predicted Emoji: ❤
#
# Text: WE LOVE YOU @user ️ ️#Repost @user ・・・My choir @user had the…
#
# Predicted Emoji: ❤
#
# Text: U Knew though #Balmain @ H&amp;M F Street
#
# Predicted Emoji: 🔥
#
# Text: So lucky to have a sister like you @user @ Fitness For 10 - Mankato
#
# Predicted Emoji: ❤
#
# Text: The Bride Dom and I!!!! Love yah @user !!! Welcome To The Family!!! #MoodyKindOfLove…
#
# Predicted Emoji: ❤
#
# Text: Just casually leaning on a wall ya know . But you should go check out my YouTube in my bio…
#
# Predicted Emoji: 😂
#
# Text: The most perfect night with the most perfect boy. Thank you for everything. I love you @user
#
# Predicted Emoji: ❤
#
# Text: Home is where the selfie lighting is @ Tiverton, Rhode Island
#
# Predicted Emoji: 📸
#
# Text: #WAKEUP Fridayyyyyyyyyy ____________________________________#BigLipMorningShow #6to10am…
#
# Predicted Emoji: 😂
#
# Text: Love starts with u 1st #Thecontroversialparty #always @ Parkway
#
# Predicted Emoji: ❤
#
# Text: Johnny ️ - Drinking a Guinness Draught by @user at @user —
#
# Predicted Emoji: ❤
#
# Text: Getting ready for a ##newborn session and Sam decided that heating pad felt good on his booty …
#
# Predicted Emoji: 🔥
#
# Text: behind the scenes. @user and staronfox coming this FALL! get ready! @ FOX
#
# Predicted Emoji: 📸
#
# Text: GRANNYz BABY! @ East Side Of Harlem
#
# Predicted Emoji: ❤
#
# Text: Mermaid Monday Happy TTP Halloween week! @ To The Pointe Dance &amp; Pilates Centre
#
# Predicted Emoji: ✨
#
# Text: Facts be you- nobody built like you never let someone change you…
#
# Predicted Emoji: 💯
#
# Text: Haven't posted in a while so here's a picture of a butterfly I swear I didn't camp out at the…
#
# Predicted Emoji: 😂
#
# Text: When your office for the day is a warehouse full of dead stock @ Tacoma, Washington
#
# Predicted Emoji: 😂
#
# Text: Trying to get @user back for getting the real thang @ Din…
#
# Predicted Emoji: 😂
#
# Text: @ Washington, District of Columbia
#
# Predicted Emoji: 🇺🇸
#
# Text: Happy 4th y'all @ Cedar Rapids Freedom Festival
#
# Predicted Emoji: 🇺🇸
#
# Text: New song dropping New Year's Eve "This Side" @ Richmond, Virginia
#
# Predicted Emoji: 🔥
#
# Text: @user lmao! stop
#
# Predicted Emoji: 😂
#
# Text: i told this scary man that Jesus loves him i look so bad i’m so sorry but i love these people…
#
# Predicted Emoji: 😍
#
# Text: 4th of July in Disney World @ Magic Kingdom, Walt Disney World, Orlando
#
# Predicted Emoji: 🇺🇸
#
# Text: @user a pipe delimited array to input many at once would be nice, I’ll definitely provide feedback.
#
# Predicted Emoji: 😎
#
# Text: Blush is my new favorite neutral This adorable sweater from @user is up #ontheblog…
#
# Predicted Emoji: 😍
#
# Text: When my customers are happy, I'm happy. "My Mother's Keeper", makes history again. We…
#
# Predicted Emoji: ❤
#
# Text: Los amo #trex #disneysprings #familia @ Disney Springs
#
# Predicted Emoji: ❤
#
# Text: Jeremiah is dumbbbb
#
# Predicted Emoji: 🔥
#
# Text: beauty bloody with house-smoked paprika and just the right amount of horseradish. @ The Osprey…
#
# Predicted Emoji: 🔥
#
# Text: Skinny Cousin I didn’t even knew you existed. ️ ️ @ Deli Board
#
# Predicted Emoji: 😂
#
# Text: Con mi vidita @ Centennial Olympic Park
#
# Predicted Emoji: ❤
#
# Text: When you're in the video they're using for training. …
#
# Predicted Emoji: 😂
#
# Text: The Grind is a must . #Shoutout #DMV &amp; gbt2x For This ass beat #dmv #music #atl…
#
# Predicted Emoji: 😂
#
# Text: Block isn't the same without our favorite transfer @ The Ohio…
#
# Predicted Emoji: ❤
#
# Text: You are not required to set yourself on #fire to keep other people warm!! Don't become…
#
# Predicted Emoji: 🔥
#
# Text: @ Blue Goose Cantina
#
# Predicted Emoji: ❤
#
# Text: Date night! benstagram99 Thanks to moebrown89 #Arrival @ Carmike Cinemas - Patton Creek 15 + IMAX
#
# Predicted Emoji: ❤
#
# Text: Happy Friday the 13th!!! @ Custom Fit at Bob's Gym
#
# Predicted Emoji: 😎
#
# Text: Good Morning Las Vegas @ Luxor Hotel and Casino
#
# Predicted Emoji: ☀
#
# Text: New toys from kayleigh_fkirons @user at the @user @ Ink Mania
#
# Predicted Emoji: ✨
#
# Text: Loc Retwist and Style with Fashion Colors #Locs #PhillyLocs #PhillyLocStar #Loctician…
#
# Predicted Emoji: 📸
#
# Text: "Mama looked into me and saw something worth believing in, long before I believed in myself."…
#
# Predicted Emoji: ❤
#
# Text: My last breakfast in #SFo was such a treat. This Dungeness Crab Melt was sheer perfection with…
#
# Predicted Emoji: 😍
#
# Text: It’s finally game day again @ UCF Softball Complex
#
# Predicted Emoji: ❤
#
# Text: Good morning #losangeles #fashionblogger @ Millennium Biltmore Hotel Los Angeles
#
# Predicted Emoji: ✨
#
# Text: FrontRow Band is BACK in Toshi.!.! TODAY is the 1st day of July 2016 and the 1st day of this…
#
# Predicted Emoji: 🇺🇸
#
# Text: *30% off site wide* code: NOVEMBER #shopsmart #supportsmallbusiness #womenempowerment…
#
# Predicted Emoji: ✨
#
# Text: When activity specialist go to Walmart! #walmart @ Iroquois Springs
#
# Predicted Emoji: 😂
#
# Text: Great crew of community supporters - @user leadership, staff, and board members. ️ @ The Omar
#
# Predicted Emoji: ❤
#
# Text: Another day at the office... er, #atTCM. #Repost @user with repostapp.・・・@themomista…
#
# Predicted Emoji: 📸
#
# Text: Our favorite place in the world: the beach. #familyvacation #seabreeze @ Ocean Shores Jetty
#
# Predicted Emoji: ☀
#
# Text: so thankful for you @ Oklahoma State University
#
# Predicted Emoji: ❤
#
# Text: "Life isn't about finding yourself. Life is about creating yourself." @ San Francisco, California
#
# Predicted Emoji: ✨
#
# Text: Venice Magazine launch with my gal pals . #venice #venicemagazine #bbtcenter #sofloliving…
#
# Predicted Emoji: ❤
#
# Text: Living the Habanero life! #habaneros #habaneropeppers #somelikeithot #putitinabasket #vamade @user
#
# Predicted Emoji: ❤
#
# Text: Gas @ Los Angeles, California
#
# Predicted Emoji: 😂
#
# Text: USA has freedom of speech alright @ San Francisco, California
#
# Predicted Emoji: 🇺🇸
#
# Text: @user i was joking damn
#
# Predicted Emoji: 😂
#
# Text: by @user @ Oakland, California
#
# Predicted Emoji: 📸
#
# Text: I kept hearing my phone ring I thought it was an amber alert it turned out being a tornado
#
# Predicted Emoji: 😂
#
# Text: My little curly had so much fun bowling for the 1st time, this picture makes me laugh so much.…
#
# Predicted Emoji: 😂
#
# Text: (@ Pasta Lovers Trattoria in New York, NY)
#
# Predicted Emoji: 😍
#
# Text: Can't wait for my birthday. Ill be nasty 1⃣9⃣ #MarchWhereYouAt
#
# Predicted Emoji: 😂
#
# Text: Got dinner with my ladies today @ Terroni DTLA
#
# Predicted Emoji: ❤
#
# Text: @ Sandy Hook Beach
#
# Predicted Emoji: ☀
#
# Text: Toro mille-feuille ️ ️ ️ Layered of a few days aged Toro melts in my mouth.…
#
# Predicted Emoji: 😍
#
# Text: After a lovely yoga class my reward a traditional Indian mango lassi #yoga #yogalove #yogatime…
#
# Predicted Emoji: ✨
#
# Text: Experiencing first hand the dire need for #WomensHealthcare. We must look out for each other! @user @user ️
#
# Predicted Emoji: 😂
#
# Text: Son, you played my tune! #goodeats, ##nyc ️, #restaurants @ Sons of Essex
#
# Predicted Emoji: ❤
#
# Text: Yup, I’ve had enough internet for today, I think @ Columbia, Missouri
#
# Predicted Emoji: 😂
#
# Text: seeing @user in concert is truly a once in a lifetime experience i have the chills it was fucking phenomenal
#
# Predicted Emoji: 🔥
#
# Text: Always on an adventure @ Joe's Valley
#
# Predicted Emoji: ❤
#
# Text: Freshly pulled from being electroformed This glowing, rainbow-filled Angel Aura Quartz Pendant…
#
# Predicted Emoji: ✨
#
# Text: I wanna get lost in this moment w/ @user @ The Fox Theatre
#
# Predicted Emoji: ❤
#
# Text: Open House weekend is THIS weekend. Get excited and bring your friends #purebarrefranklin…
#
# Predicted Emoji: 🔥
#
# Text: Tiaira think I'm playing
#
# Predicted Emoji: 😂
#
# Text: Gotta love Tennessee @ Pigeon Forge, Tennessee
#
# Predicted Emoji: ❤
#
# Text: I got many characters...don't bring out the wrong ones! #grimey #likeforlikes #followme…
#
# Predicted Emoji: 😂
#
# Text: Our lovely LIVE Inc Mentor Ms. Sonya #journaling #LIVEInc #balchspringsreccenter…
#
# Predicted Emoji: ❤
#
# Text: Sept. 8th we lit Persorming live at the #deltafair with bryson_todd and shinobigang @ Delta…
#
# Predicted Emoji: 🔥
#
# Text: •NEVER LOSE THAT SMILE , FROM HERE EVERYTHING IS BLUE... HIS PILLS, HIS HANDS, HIS JEANS AND…
#
# Predicted Emoji: 😂
#
# Text: CATurday with my best friend @ Commonwealth Stadium
#
# Predicted Emoji: ❤
#
# Text: This! #MotivationalHealthCoach #Repost stefharr (get_repost) @ Size Healthy
#
# Predicted Emoji: 🔥
#
# Text: 3D computer-generated model... actually it's a real photo of the Austin Apple facility. @user
#
# Predicted Emoji: 😂
#
# ...
#
# Predicted Emoji: ❤
#
# Text: @user throwin it down last night at Empire Control Room @ Empire Control Room &amp; Garage
#
# Predicted Emoji: 📸
#
# Text: Prom with my boy @ Milwaukee Art Museum
#
# Predicted Emoji: ❤
#
# Text: Reunited buds @ Kent State
#
# Predicted Emoji: ❤
#
# Text: workshopping and transposing this yesterday was a pleasure, congratulations and look forward…
#
# Predicted Emoji: 😍
#
# Text: @user #CarloSlabino @ East Nashville, Tennessee
#
# Predicted Emoji: ❤
#
# Text: How lauryn_hinckley felt about Superman Bananas today.... she doesn’t complain…
#
# Predicted Emoji: 😂
#
# Text: Fun fact: it took way too long for everyone to be ready for this photo. #lovemygirls @user
#
# Predicted Emoji: 😂
#
# Text: 10.13.2017 | Got a postcard from my second home on #fridaythe13th how lovely! But I miss my…
#
# Predicted Emoji: ❤
#
# Text: regram @user comes the sun! #ItsAmazingOutThere #SunriseWeather : @user @user
#
# Predicted Emoji: ☀
#
# Text: It's official! with an honor of 2decades #20th #instagrammer…
#
# Predicted Emoji: 🇺🇸
#
# Text: Taxi, anyone!? (@ City of Los Angeles in Los Angeles, CA)
#
# Predicted Emoji: 😂
#
# Text: ALERT SATURDAY OCTOBER 28TH #BLACKENTOURAGE PRESENTS #SAINTSANDSINNERS…
#
# Predicted Emoji: 🔥
#
# Text: "I knew I loved you when home went from a place to a person" @ Currie Golf Course
#
# Predicted Emoji: ❤
#
# Text: hi friends summer Wesley tonight at the office, we're continuing our study of 1 Corinthians.…
#
# Predicted Emoji: ☀
#
# Text: Uh oh, my favorite burger place now serves beer @ Master Burger &amp;…
#
# Predicted Emoji: 😍
#
# Text: There's something about December @ CF Toronto Eaton Centre
#
# Predicted Emoji: ❤
#
# Text: #lmao @ Boston, Massachusetts
#
# Predicted Emoji: 😂
#
# Text: My bro gonna keep giving u this #WORK @user hypebeast #ALMIGHTY #GXFR @ Masjid…
#
# Predicted Emoji: 💯
#
# Text: So much fun #ChaseRice #TheCadillacThree #JordanDavis #countrymusic @ Seven Flags Event Center
#
# Predicted Emoji: ❤
#
# Text: “I've got blisters on me fingers!” #YesMan #JimCarrey @user
#
# Predicted Emoji: 😍
#
# Text: Go get it NOW @user #UnifyOrDie #GoldCollarMg #NewMusic #RealRap #facts #power #thereal…
#
# Predicted Emoji: 😂
#
# Text: When your baby girl(she's 21 ), gives you socks, dammit you wear…
#
# Predicted Emoji: ❤
#
# Text: "Gosh Minnie, you've always been a princess to me!" | While I'm saddened about the ending of…
#
# Predicted Emoji: 😍
#
# Text: @user he went to high school with my roommate
#
# Predicted Emoji: ❤
#
# Text: Happy Moving-to-London day! I cannot wait to come visit! Now kick some butt #londoncalling…
#
# Predicted Emoji: 😉
#
# Text: All month long I will share some fun facts in honor of #LIAM Life Insurance Awareness Month ️…
#
# Predicted Emoji: ❤
#
# Text: Balayage by yours truly Michelle wanted a low maintenance color while she travels for 8…
#
# Predicted Emoji: 😍
#
# Text: #GdlFashion @user Autographs from No. 18! #BroncosCountryPlayoffs : Charlie Riedel/AP @ Denver…
#
# Predicted Emoji: 📸
#
# Text: All. The. Turkey. #thanksgiving Gifford Photographic Collection @ Oregon State University
#
# Predicted Emoji: 📸
#
# Text: Shhhhhaaaaaaooww!!!! #tulareoutlet @ Grocery Outlet
#
# Predicted Emoji: ❤
#
# Text: The sign clearly states $0.25 per... always trying to get something for nothing #readthesigns…
#
# Predicted Emoji: 🇺🇸
#
# Text: Ready to start my adventure at AP!! #gogovs @ Austin Peay State…
#
# Predicted Emoji: 📸
#
# Text: Fridayyyy!!!! Don't kill my vibe #ootd #friday #fashionblogger #Toronto #blog #blogger…
#
# Predicted Emoji: ✨
#
# Text: Movie night with mi tesoro #thelovewitch #cinefamily #la @ The Cinefamily
#
# Predicted Emoji: ❤
#
# Text: Easily the best part of my day today #MyNewMan #GingerbreadMan #gingerbread #cookies #sweets…
#
# Predicted Emoji: 😍
#
# Text: Jim Gorman Golf Outing 2017 with these beauties! ️ @ Gleneagles…
#
# Predicted Emoji: ❤
#
# Text: So no date night on Sunday cause I got something way more special .…
#
# Predicted Emoji: ❤
#
# Text: MPCS Annual Student Retreat. Lunchtime is crazy fun!! #sharptopcove #mppatriotrelationships @user
#
# Predicted Emoji: ❤
#
# Text: DAVE EAST ABOUT TO SPIT THAT @ Trifecta Lounge - Richmond
#
# Predicted Emoji: 🔥
#
# Text: Say hello to Frank Best salon experience I have ever had, and that's not even including…
#
# Predicted Emoji: 😍
#
# Text: It was a beautiful day yesterday celebrating love Congrats shmezz and Tara! #love #wedding…
#
# Predicted Emoji: ❤
#
# Text: ️ &amp; Blessings To You And Yours Thanks To Every Who Showed Me Love I Owe Y'all 1 #HOTBOY @user
#
# Predicted Emoji: ❤
#
# Text: Sweet potato summer lovin! #Gnocchi ️ @ Saint Petersburg, Florida
#
# Predicted Emoji: ❤
#
# Text: Pho mi amor! #Pho #OceanBeach #TourUnicos #Siddhartha @ OB Noodle House Bar 1502
#
# Predicted Emoji: 😍
#
# Text: So uhhhh. I got the COOLEST MUG EVER @ Bowmanville, Ontario
#
# Predicted Emoji: 😎
#
# Text: For the Love of donuts #samdog #mylife #imgoingtomisshim #dogsofinstagram #dogs…
#
# Predicted Emoji: ❤
#
# Text: Uncle Dalton loves you, Audrey. @ Gilbertown, Alabama
#
# Predicted Emoji: ❤
#
# Text: @user creature comforts thanks my dear #apotheke #woods…
#
# Predicted Emoji: ❤
#
# Text: The New Flex for the Apple Watch Shoutout @user for the hookup!#Timeless…
#
# Predicted Emoji: 🔥
#
# Text: So I just gotta have this bracelet! @ Knoebels Amusement Resort
#
# Predicted Emoji: 😂
#
# Text: my team trading on their day off!! Monday academy #braids and #blowouts with @user
#
# Predicted Emoji: 😍
#
# Text: What a wonderful weekend with a Wonderful girl . From aimlessly…
#
# Predicted Emoji: ❤
#
# Text: Obsessed with her @user #BebeRexha @ Premiere Theaters Oaks 10
#
# Predicted Emoji: 😍
#
# Text: He was mad af at me for cutting his too much of his hair off @ North Monroe, Louisiana
#
# Predicted Emoji: 😂
#
# Text: Gotta #happyhour $2 bud Miller and Coors. But unfortunately cool hipster bar means no...
#
# Predicted Emoji: 😎
#
# Text: Birthday Dinner.... we love you Faith!!! #happybirthdayfaith …
#
# Predicted Emoji: ❤
#
# Text: At the YMCA and ....... @ YMCA Stair Climb for Los Angeles
#
# Predicted Emoji: 😂
#
# Text: My favorite time of the year with my favorite girls @ Dance Concept
#
# Predicted Emoji: ❤
#
# Text: We are here safe and all checked in #CityBreak #NewYorkCity @user
#
# Predicted Emoji: ❤
#
# Text: In support of the Henry Street Settlement. Thank for the invite @user @user :…
#
# Predicted Emoji: ❤
#
# Text: Tsssss en In-N-Out Burger
#
# Predicted Emoji: 🔥
#
# Text: #veganstreetfair is #northhollywood @ Vegan Street Fair
#
# Predicted Emoji: 😍
#
# Text: our hearts are already full and ready to inspire the women back home ️ #fightinghunger @ JW…
#
# Predicted Emoji: ❤
#
# Text: One of the best things about this boat is that you don’t need a small dinghy to reach the…
#
# Predicted Emoji: 😂
#
# Text: I love this city #kansascity #skyline #boulevard #boulevardbrewery #foreverroyal #sightseeing…
#
# Predicted Emoji: ❤
#
# Text: No filter necessary. @ Clifton Park, New York
#
# Predicted Emoji: 📸
#
# Text: I made @user stand next to me while I took this picture so I looked less lame @ Vaughan's…
#
# Predicted Emoji: 😂
#
# Text: Take care of them 1st den I'm ready for a dawg ass weekend @user
#
# Predicted Emoji: 😂
#
# Text: Brothers . #lakelife #brotherlylove @ Linn Creek, Missouri
#
# Predicted Emoji: ❤
#
# Text: : trb_photography_kentucky @user @user #speedycreekband #tourlife @ Master…
#
# Predicted Emoji: 📸
#
# Text: My set is complete. #newseries #comingsoon #yabooks #yascifi #yalovin #dystopiabooks…
#
# Predicted Emoji: 🔥
#
# Text: Maya is just as excited as I am #christmasfamilyreunion2015 @ Lithia Springs, Georgia
#
# Predicted Emoji: ❤
#
# Text: #mcm Jj I know I'm stubborn and annoying and I don't always do…
#
# Predicted Emoji: ❤
#
# Text: Up late playing with a new editing dimension. Edits mean everything!!#latenight #apple…
#
# Predicted Emoji: 📸
#
# Text: ️ holidays twinkle.sprinkles Micky badge is being worn lots @ Magic…
#
# Predicted Emoji: 🎄
#
# Text: Denver Fashion Week: Night 1 // Denver, CO @ City Hall
#
# Predicted Emoji: ✨
#
# Text: #fourthofjuly #views #home #happygirl #free @ The Standard Spa, Miami Beach
#
# Predicted Emoji: ❤
#
# Text: Stay-Groomed-Rite #Layrite #Menshaircut #Fl #Tbt #Florida #Miamibeachhair…
#
# Predicted Emoji: 😂
#
# Text: Gold #alchemy #adjustable #rings. lots &amp; lots of them ....#instagood #womensfashion…
#
# Predicted Emoji: ✨
#
# Text: see ya soon my little goons @ Westlake, Ohio
#
# Predicted Emoji: ❤
#
# Text: She's beautiful #wcw @ Pots
#
# Predicted Emoji: 😍
#
# Text: Work crew...love them! #9300andmerrickcrew #strikeapose #tgif @ Off the Wagon Bar and Grill
#
# Predicted Emoji: ❤
#
# Text: glad i got to end summer with my bestie @ Norris Lake
#
# Predicted Emoji: ☀
#
# Text: Took a trip to the top of the mountain and drove into a winter wonderland Olivia was napping…
#
# Predicted Emoji: ✨
#
# Text: @user for obvious reasons she's a calico.
#
# Predicted Emoji: 😂
#
# Text: Clown hair #douglasj #cosmetologylife love this ladies @ Douglas J Aveda Institute
#
# Predicted Emoji: ❤
#
# Text: &amp; Repeat #FitSpaceNYC #fitness #fitlife #fitisthemission #fit #liftlife #livefit #lift…
#
# Predicted Emoji: 💯
#
# Text: #photography #photo #portrait #studio #nyc latest portrait by me of photographer philabusters @user
#
# Predicted Emoji: 📸
#
# Text: Bryson Tiller kinda night..
#
# Predicted Emoji: 😂
#
# Text: Klever Klippers!! And they got the Tampa Bow Tie Guy on the flyer though!! Part n all …
#
# Predicted Emoji: 😂
#
# Text: @user - Breakeven @ The Riviera Theatre
#
# Predicted Emoji: ❤
#
# Text: Welcome Snow @ Chicago, Illinois
#
# Predicted Emoji: ❤
#
# Text: Running back to my spot on left bench #Turkeybowl2017 : allysahhh @ Benchwarmers
#
# Predicted Emoji: 😂
#
# Text: I will always be fat @ NoHo
#
# Predicted Emoji: 😂
#
# Text: I swear a fresh fade will make your week #fresh #mvmt #mvmtshades #clean #fade…
#
# Predicted Emoji: 😎
#
# Text: Never lost hope, never will #tbt @ New York, New York
#
# Predicted Emoji: 📸
#
# Text: well, that was an amazing night. @ Chateau Del Mar
#
# Predicted Emoji: ❤
#
# Text: This place is so cute and so is my husband @ The Magnolia Market Silos
#
# Predicted Emoji: 😍
#
# Text: "Surround yourself with only people who are going to lift you higher." -Oprah Winfrey •••I…
#
# Predicted Emoji: ✨
#
# Text: this stress ain't no joke
#
# Predicted Emoji: 😂
#
# Text: A great shot from the #CollegiateClassic hosted by texasstatewake behind ther @user #A24 …
#
# Predicted Emoji: 📸
#
# Text: Friendship is so valuable. Our greatest gift in life. Thanks to those who care for me ️ @user
#
# Predicted Emoji: ❤
#
# Text: ️ @ Dillion Beach
#
# Predicted Emoji: ❤
#
# Text: Check out this cutie who showed off her splits in our Wed night combo class! @ Rockwall Dance…
#
# Predicted Emoji: 😍
#
# Text: @user oh my gosh the stories I have!... ....#joysofparenthood
#
# Predicted Emoji: 😍
#
# Text: He's terrified of a little drone! #lifewithranger @ Ardmore, Oklahoma
#
# Predicted Emoji: 😂
#
# Text: Finally Bonfire weather in Florida!! #florida #bonfire #bonfirenight @ Bloomingdale, Florida
#
# Predicted Emoji: 🔥
#
# Text: One of the best views from this summer #dcifinals2017 @ Lucas Oil…
#
# Predicted Emoji: 😍
#
# Text: @user @ Maryland
#
# Predicted Emoji: ❤
#
# Text: With the New Year upon us we’re at the peak of our respective shifts and refocuses. Friends and…
#
# Predicted Emoji: ✨
#
# Text: @ Heavenly Hair
#
# Predicted Emoji: 😍
#
# Text: The pictures caption themselves @ Minnesota
#
# Predicted Emoji: 😂
#
# Text: Love you @ Texas Tech University
#
# Predicted Emoji: ❤
#
# Text: Fall in love with Virginia @ Virginia
#
# Predicted Emoji: ❤
#
# Text: Couldn't have asked for a better date @ Broneys Alumni Grill
#
# Predicted Emoji: ❤
#
# Text: Panhellenic Council Spotlight Name:Elsy VerdugoMajor: Spanish and English LiteratureYear:…
#
# Predicted Emoji: ✨
#
# Text: #mcm, my bestfriend, my boyfriend, and my everything @ JOHN PAUL…
#
# Predicted Emoji: ❤
#
# Text: Enjoying the #City while #Shopping doing what #Girls do #NewYork #NYC #MakingMemories…
#
# Predicted Emoji: ☀
#
# Text: ️ this guy #theamericansector #dinnerafterdark @ The American Sector
#
# Predicted Emoji: ❤
#
# Text: My happy place @ Mountain Drive
#
# Predicted Emoji: ❤
#
# Text: Times Square daylight (at Times Square) [pic] —
#
# Predicted Emoji: 📸
#
# Text: #Reiki is a great self care addition @ Satori324
#
# Predicted Emoji: ✨
#
# Text: Thank you for the birthday wishes @ Jose Rizal Bridge
#
# Predicted Emoji: ❤
#
# Text: chasing sunsets with carlyjean1....#explore #outdoors #adventure #hike #hiking #bay…
#
# Predicted Emoji: ❤
#
# Text: Love them both so much. . #pawpawlovesaria #memawlovesyouinfinity…
#
# Predicted Emoji: ❤
#
# Text: j stone (excuse my ugliness lmao) @ Madison Theater
#
# Predicted Emoji: 😂
#
# Text: 5thandtaylor #CakeCakeCakeCake #TheKing #Elvis @ 5th &amp; Taylor
#
# Predicted Emoji: ❤
#
# Text: I'm his fangirl for life terrybratsch @ The Brick Saloon
#
# Predicted Emoji: 😍
#
# Text: Another year with the Koel boys @ Novato, California
#
# Predicted Emoji: ❤
#
# Text: After hours. #LFEfraternity #LPhiE @ Syracuse University
#
# Predicted Emoji: 😂
#
# Text: You're simply the best! Happy belated 30th, Loz...so glad we could all be together @ New York,…
#
# Predicted Emoji: ❤
#
# Text: #EYinnovationspace #Ernst&amp;Young #microsoft #surfacehub want one but that's $20 grands @ Ernst &amp;…
#
# Predicted Emoji: ✨
#
# Text: Glowing #higlightoverdose @ Disneyland
#
# Predicted Emoji: ✨
#
# Text: I keep missing #mcm y’all. You already know it’s this rude handsome fella here. @ Hardee's
#
# Predicted Emoji: ❤
#
# Text: #YTNextUp #classof2016 @ YouTube Space LA
#
# Predicted Emoji: 🔥
#
# Text: North Dallas home sales for SeptemberSales were up 5 percent. The average sales price dropped…
#
# Predicted Emoji: 🔥
#
# Text: My view at work today #fall #fallcolors #nature @ Healing Transitions
#
# Predicted Emoji: 😍
#
# Text: Mom and daughter... a few years ago #throwbackthursday @ Mississauga, Ontario
#
# Predicted Emoji: ❤
#
# Text: Highlight of the night @ Divots Concert Series
#
# Predicted Emoji: 🔥
#
# Text: She is so proud of her ugly Christmas sweater cookie!! emimax2899 @ Church of Jesus Christ of…
#
# Predicted Emoji: 🎄
#
# Text: Welcome home my g jerzdh407856 linked more then a decade ago but they ont hear me tho…
#
# Predicted Emoji: ❤
#
# Text: Ahhhhh, two birds and a smile, no less. How do ya like that? LMAO @ Temecula, California
#
# Predicted Emoji: 😂
#
# Text: Cuteness overload @ Thompson, Iowa
#
# Predicted Emoji: 😍
#
# Text: He is the most beautiful creature I've ever seen #littleseattleite #lovemyson #handsome…
#
# Predicted Emoji: 😍
#
# Text: Squirrel is trying to cool down Priscilla one lick at a time . #labstagram #dogsofinstagram…
#
# Predicted Emoji: 😂
#
# Text: My smile says it all @ Millennium Park
#
# Predicted Emoji: 😊
#
# Text: Got One For XMas... too cheap to buy these myself . @user #PleasePutMeInARoomWith Candles
#
# Predicted Emoji: 🎄
#
# Text: READ BELOW FOR EXTRA GIVEAWAY ENTRIES!!! can win one of these amazing book sleeves from…
#
# Predicted Emoji: ✨
#
# Text: #babysiegfried @ Longue Vue Club and Golf Course
#
# Predicted Emoji: 😎
#
# Text: #early mixing my beautiful color collection thanks to fineartstore6920#pbsartistopenstudio…
#
# Predicted Emoji: 😍
#
# Text: SUMMER HAIR SPECIALS: #braids #longbraids #feedinbraids #beauty #braids #microbraids #crochet…
#
# Predicted Emoji: 😍
#
# Text: 76-degrees and everything's still nice and green! I FL! #nofilter @ University of North Florida
#
# Predicted Emoji: ☀
#
# Text: He looooves the vet (he's fine, just getting a physical) #pomeranian #pomsofinstagram…
#
# Predicted Emoji: 😂
#
# Text: life isn't so perfect but your outfits can be #stayclassy @ Chinatown, Los Angeles
#
# Predicted Emoji: ✨
#
# Text: Happy 4th @ Stevenson Park
#
# Predicted Emoji: 🇺🇸
#
# Text: #Shareyourears disneyland ️ #magicplace #mickeymouse #smile en Disneyland
#
# Predicted Emoji: ✨
#
# Text: Sorry we didn't get you a present.. Splurged on a new sweater instead. #woreitoutofthestore…
#
# Predicted Emoji: 🎄
#
# Text: Every heart has it's secret sorrows.#sadnessstrikesme @ Mt. Washington Auto Road
#
# Predicted Emoji: ❤
#
# Text: The Jeese Bag makes my heart skip a BEAT!Hoe does it make you feel?#kisakisafashion…
#
# Predicted Emoji: ❤
#
# Text: Rest In Peace, Nana. thanks for playing cards @ Lynn, Massachusetts
#
# Predicted Emoji: ❤
#
# Text: I jus wan EAT #chowtime #swt30 @ Hartford, Connecticut
#
# Predicted Emoji: 😂
#
# Text: Playing Bloon SuperMonkey 2 #bloonsupermonkey2 #bloontd @user
#
# Predicted Emoji: 🔥
#
# Text: Best Snow-cone I've EVER had!!! #bahamabucks #youhavetotryit…
#
# Predicted Emoji: 😍
#
# Text: You making my life better is just part of your blessing.
#
# Predicted Emoji: ❤
